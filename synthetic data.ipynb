# %%
# %pip install Faker
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/faker/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/faker/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/faker/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/faker/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/faker/
# Collecting faker
#   Downloading Faker-25.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\user\anaconda3\envs\asklepios\lib\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\asklepios\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Downloading Faker-25.2.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.8 MB 445.2 kB/s eta 0:00:04
#     --------------------------------------- 0.0/1.8 MB 281.8 kB/s eta 0:00:07
#    -- ------------------------------------- 0.1/1.8 MB 479.1 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.8 MB 547.6 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.8 MB 481.4 kB/s eta 0:00:04
#    --- ------------------------------------ 0.2/1.8 MB 484.3 kB/s eta 0:00:04
#    ---- ----------------------------------- 0.2/1.8 MB 513.4 kB/s eta 0:00:04
#    ------ --------------------------------- 0.3/1.8 MB 682.7 kB/s eta 0:00:03
#    ------ --------------------------------- 0.3/1.8 MB 705.4 kB/s eta 0:00:03
#    ---------- ----------------------------- 0.5/1.8 MB 894.8 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.8 MB 983.5 kB/s eta 0:00:02
#    ------------- -------------------------- 0.6/1.8 MB 1.0 MB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.8 MB 1.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.8 MB 1.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 1.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 1.7/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.1 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-25.2.0
# Collecting Faker
#   Using cached Faker-25.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\user\anaconda3\envs\asklepios\lib\site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\asklepios\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Using cached Faker-25.2.0-py3-none-any.whl (1.8 MB)
# Installing collected packages: Faker
# Successfully installed Faker-25.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
from datetime import datetime, timedelta

fake = Faker()

# Number of samples
n_samples = 57592

# Generate random data
data = []

for _ in range(n_samples):
    dob = fake.date_of_birth(minimum_age=18, maximum_age=80).strftime("%Y-%m-%d")
    dob_date = datetime.strptime(dob, "%Y-%m-%d")
    
    date_confirmed_hiv_positive = fake.date_between(start_date=dob_date + timedelta(days=6570), end_date='today').strftime("%Y-%m-%d")  # 6570 days = 18 years
    date_confirmed_hiv_positive_date = datetime.strptime(date_confirmed_hiv_positive, "%Y-%m-%d")

    start_date_current_art = fake.date_between(start_date=date_confirmed_hiv_positive_date, end_date='today').strftime("%Y-%m-%d")
    start_date_current_art_date = datetime.strptime(start_date_current_art, "%Y-%m-%d")

    date_first_visit = fake.date_between(start_date=dob_date + timedelta(days=6570), end_date='today').strftime("%Y-%m-%d")
    date_first_visit_date = datetime.strptime(date_first_visit, "%Y-%m-%d")

    date_most_recent_visit = fake.date_between(start_date=date_first_visit_date, end_date='today').strftime("%Y-%m-%d")

    date_of_exit = fake.date_between(start_date=date_first_visit_date, end_date='today').strftime("%Y-%m-%d")

    data.append([
        fake.unique.uuid4(),  # Patient ID
        dob,
        random.choice(['Male', 'Female']),
        date_confirmed_hiv_positive,
        random.choice(['Yes', 'No']),
        random.choice(['Regimen A', 'Regimen B', 'Regimen C']),
        start_date_current_art,
        date_first_visit,
        date_most_recent_visit,
        random.randint(200, 1500),  # CD4 count at first visit
        random.randint(20, 200000),  # Viral load at first visit
        random.randint(200, 1500),  # CD4 count at most recent visit
        random.randint(20, 200000),  # Viral load at most recent visit
        (date_first_visit_date - dob_date).days // 365,  # Age at first visit
        random.choice(['Employed', 'Unemployed', 'Student', 'Retired', 'Other']),
        random.choice(['Primary education', 'Secondary education', 'Tertiary education', 'Other']),
        random.choice(['Low', 'Medium', 'High', 'Prefer not to say']),
        random.choice(['Single', 'Married', 'Divorced', 'Widowed', 'Other']),
        random.choice(['None', 'Alcohol', 'Tobacco', 'Illicit drugs', 'Other']),
        random.choice(['None', 'Diabetes', 'Hypertension', 'Tuberculosis', 'Hepatitis B/C', 'Cardiovascular diseases', 'Other']),
        random.choice(['None', 'Fever', 'Weight loss', 'Night sweats', 'Cough', 'Other']),
        random.choice(['Healthy', 'Average', 'Poor']),
        random.choice(['Regular', 'Occasional', 'None']),
        random.choice(['Always', 'Often', 'Sometimes', 'Rarely', 'Never']),
        random.randint(0, 30),  # Missed doses in the last month
        random.choice(['Yes', 'No']),
        (datetime.strptime(date_most_recent_visit, "%Y-%m-%d") - date_first_visit_date).days,  # Duration of followups in days
        date_of_exit,
        random.choice(['Transferred out', 'Died', 'Lost to followups', 'Other'])
    ])

# %%
# Create DataFrame
data = pd.DataFrame(data, columns=[
    'Patient ID', 'Date of birth', 'Gender', 'Date confirmed HIV positive',
    'Previous ART exposure', 'Current ART regimen', 'Start date of current ART',
    'Date of first visit', 'Date of most recent visit', 'CD4 count at first visit',
    'Viral load at first visit', 'CD4 count at most recent visit', 'Viral load at most recent visit',
    'Age at first visit', 'Employment status', 'Education level', 'Income level', 'Marital status',
    'Substance use history', 'Comorbidities', 'Reported symptoms', 'Dietary habits', 'Physical activity',
    'Adherence to ART', 'Missed doses in the last month', 'Adverse event', 'Duration of followups',
    'Date of exit from the study', 'Reason for exit'
])

# %%
data.head()
# Out:
#                              Patient ID Date of birth  Gender  \
# 0  bacdb318-38ed-4bf1-ac9a-104183b7faa9    1955-10-06    Male
# 1  95e84dde-ab5b-468f-afa3-94d4687aa71d    1994-07-01  Female
# 2  6a0f9de6-50bd-41f3-8681-72dd7b657a61    1980-01-23    Male
# 3  356b799b-cb8a-4f4c-a250-441b76273150    1961-12-07    Male
# 4  5e9c4ec5-e7ed-4ef7-b944-a27a18ad4dff    2005-01-09    Male
#
#   Date confirmed HIV positive Previous ART exposure Current ART regimen  \
# 0                  2020-04-12                    No           Regimen C
# 1                  2017-10-10                   Yes           Regimen A
# 2                  2008-02-09                    No           Regimen C
# 3                  2012-01-24                   Yes           Regimen A
# 4                  2023-03-22                    No           Regimen C
#
#   Start date of current ART Date of first visit Date of most recent visit  \
# 0                2020-12-17          2004-07-06                2019-06-19
# 1                2019-04-16          2018-05-08                2020-03-31
# 2                2020-10-26          2022-05-11                2023-03-02
# 3                2017-08-29          2009-06-23                2021-08-04
# 4                2024-05-17          2024-03-31                2024-04-30
#
#    CD4 count at first visit  ...  Comorbidities  Reported symptoms  \
# 0                       372  ...       Diabetes              Fever
# 1                      1430  ...   Hypertension              Other
# 2                      1315  ...   Hypertension               None
# 3                       848  ...       Diabetes               None
# 4                      1031  ...       Diabetes              Other
#
#    Dietary habits  Physical activity Adherence to ART  \
# 0         Average            Regular           Rarely
# 1         Average               None        Sometimes
# 2         Healthy            Regular           Always
# 3            Poor            Regular            Often
# 4         Average               None            Never
#
#   Missed doses in the last month Adverse event Duration of followups  \
# 0                             30           Yes                  5461
# 1                             16            No                   693
# 2                              7           Yes                   295
# 3                             24            No                  4425
# 4                              8           Yes                    30
#
#   Date of exit from the study    Reason for exit
# 0                  2022-08-04              Other
# 1                  2020-02-19               Died
# 2                  2022-11-26  Lost to followups
# 3                  2022-08-04    Transferred out
# 4                  2024-04-22    Transferred out
#
# [5 rows x 29 columns]

# %%
#Convert to csv file
data.to_csv('Synthetic_data.csv', index=False)
